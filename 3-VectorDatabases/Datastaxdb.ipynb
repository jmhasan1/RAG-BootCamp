# %% [markdown]
# ### ASTRADB VectorStore
# Go from app idea to production with the AI Platform with Astra DB, the ultra-low latency database made for AI and Langflow, the low-code RAG IDE
# https://www.datastax.com/

# %%
# !pip install \
    "langchain>=0.3.23,<0.4" \
    "langchain-core>=0.3.52,<0.4" \
    "langchain-astradb>=0.6,<0.7"
# Out:
# Collecting langchain<0.4,>=0.3.23
#   Downloading langchain-0.3.30-py3-none-any.whl.metadata (6.4 kB)
# Collecting langchain-core<0.4,>=0.3.52
#   Downloading langchain_core-0.3.86-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-astradb<0.7,>=0.6
#   Downloading langchain_astradb-0.6.1-py3-none-any.whl.metadata (10 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain<0.4,>=0.3.23)
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain<0.4,>=0.3.23) (0.9.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain<0.4,>=0.3.23) (2.13.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain<0.4,>=0.3.23) (2.0.51)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain<0.4,>=0.3.23) (2.32.4)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain<0.4,>=0.3.23) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4,>=0.3.52) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4,>=0.3.52) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4,>=0.3.52) (4.15.0)
# Collecting packaging<26.0.0,>=23.2.0 (from langchain-core<0.4,>=0.3.52)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4,>=0.3.52) (0.16.2)
# Collecting astrapy<3.0.0,>=2.0.1 (from langchain-astradb<0.7,>=0.6)
#   Downloading astrapy-2.3.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from langchain-astradb<0.7,>=0.6) (2.0.2)
# Requirement already satisfied: deprecation~=2.1.0 in /usr/local/lib/python3.12/dist-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2.1.0)
# Requirement already satisfied: h11>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.16.0)
# Requirement already satisfied: httpx<1,>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.28.1)
# Collecting ipython>=8.0.0 (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading ipython-9.15.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pymongo>=3 (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading pymongo-4.17.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: toml<1.0.0,>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.10.2)
# Collecting uuid6>=2024.1.12 (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading uuid6-2025.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4,>=0.3.52) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (4.14.0)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (3.7.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain<0.4,>=0.3.23) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain<0.4,>=0.3.23) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain<0.4,>=0.3.23) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain<0.4,>=0.3.23) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain<0.4,>=0.3.23) (3.5.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (1.0.9)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (4.3.0)
# Collecting decorator>=5.1.0 (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading decorator-5.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.2 (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (3.0.52)
# Collecting psutil>=7 (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pygments>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2.20.0)
# Collecting stack_data>=0.6.0 (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading traitlets-5.15.1-py3-none-any.whl.metadata (10 kB)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo>=3->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (4.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.18.2->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.6->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.8.1)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading asttokens-3.0.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading langchain-0.3.30-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.1 MB/s eta 0:00:00
# Downloading langchain_core-0.3.86-py3-none-any.whl (461 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.3/461.3 kB 44.5 MB/s eta 0:00:00
# Downloading langchain_astradb-0.6.1-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# Downloading astrapy-2.3.1-py3-none-any.whl (360 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.9/360.9 kB 35.6 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 7.9 MB/s eta 0:00:00
# Downloading ipython-9.15.0-py3-none-any.whl (630 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.9/630.9 kB 51.2 MB/s eta 0:00:00
# Downloading pymongo-4.17.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 97.0 MB/s eta 0:00:00
# Downloading uuid6-2025.0.1-py3-none-any.whl (7.0 kB)
# Downloading decorator-5.3.1-py3-none-any.whl (10 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 35.1 MB/s eta 0:00:00
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 135.4 MB/s eta 0:00:00
# Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 18.7 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading traitlets-5.15.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 9.6 MB/s eta 0:00:00
# Downloading asttokens-3.0.2-py3-none-any.whl (28 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: pure-eval, uuid6, traitlets, psutil, packaging, jedi, ipython-pygments-lexers, executing, dnspython, decorator, asttokens, stack_data, pymongo, ipython, langchain-core, astrapy, langchain-text-splitters, langchain-astradb, langchain
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.2
#     Uninstalling packaging-26.2:
#       Successfully uninstalled packaging-26.2
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.8
#     Uninstalling langchain-core-1.4.8:
#       Successfully uninstalled langchain-core-1.4.8
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.11
#     Uninstalling langchain-1.3.11:
#       Successfully uninstalled langchain-1.3.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.15.0 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.3.86 which is incompatible.
# langgraph 1.2.6 requires langchain-core<2,>=1.4.7, but you have langchain-core 0.3.86 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# Successfully installed astrapy-2.3.1 asttokens-3.0.2 decorator-5.3.1 dnspython-2.8.0 executing-2.2.1 ipython-9.15.0 ipython-pygments-lexers-1.1.1 jedi-0.20.0 langchain-0.3.30 langchain-astradb-0.6.1 langchain-core-0.3.86 langchain-text-splitters-0.3.11 packaging-25.0 psutil-7.2.2 pure-eval-0.2.3 pymongo-4.17.0 stack_data-0.6.3 traitlets-5.15.1 uuid6-2025.0.1

# %%
# !pip install langchain_openai
# Out:
# Collecting langchain_openai
#   Downloading langchain_openai-1.3.5-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-core<2.0.0,>=1.4.9 (from langchain_openai)
#   Downloading langchain_core-1.4.9-py3-none-any.whl.metadata (4.7 kB)
# Collecting openai<3.0.0,>=2.45.0 (from langchain_openai)
#   Downloading openai-2.45.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (0.9.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain_openai) (0.16.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.45.0->langchain_openai) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.45.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.45.0->langchain_openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.45.0->langchain_openai) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.45.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.45.0->langchain_openai) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.45.0->langchain_openai) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.45.0->langchain_openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.45.0->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.45.0->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain_openai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain_openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain_openai) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain_openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain_openai) (3.7.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain_openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain_openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain_openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain_openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.5.0)
# Downloading langchain_openai-1.3.5-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 11.0 MB/s eta 0:00:00
# Downloading langchain_core-1.4.9-py3-none-any.whl (558 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.3/558.3 kB 33.5 MB/s eta 0:00:00
# Downloading openai-2.45.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.3 MB/s eta 0:00:00
# Installing collected packages: openai, langchain-core, langchain_openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.43.0
#     Uninstalling openai-2.43.0:
#       Successfully uninstalled openai-2.43.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.86
#     Uninstalling langchain-core-0.3.86:
#       Successfully uninstalled langchain-core-0.3.86
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.30 requires langchain-core<1.0.0,>=0.3.85, but you have langchain-core 1.4.9 which is incompatible.
# langchain-astradb 0.6.1 requires langchain-core<1.0.0,>=0.3.74, but you have langchain-core 1.4.9 which is incompatible.
# Successfully installed langchain-core-1.4.9 langchain_openai-1.3.5 openai-2.45.0

# %%
### Config
ASTRA_DB_API_ENDPOINT="https://1beaf365-fca9-432e-8d11-e6bd566158-east-2.apps.astra.datastax.com"
ASTRA_DB_APPLICATION_TOKEN="AstraCS:UQibHoJlupgvUnACFizHwATs1745618f6b2a9046b25a72378dab3f83869a940f4015681811ddb67cc438f1"

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-small",dimensions=1024, openai_api_key="YOUR_OPENAI_API_KEY")

# %%
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x7a08433b1700>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x7a0722261190>, model='text-embedding-3-small', dimensions=1024, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
from langchain_astradb import AstraDBVectorStore
vector_store = AstraDBVectorStore(
    embedding=embeddings,
    collection_name="langchain_astra_vector_test",
    token=ASTRA_DB_API_TOKEN,
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    namespace=None
)

vector_store

# %%
from langchain_core.documents import Document

document_1 = Document(
    page_content="I had chocolate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
)

documents = [
    document_1,
    document_2,
    document_3,
    document_4,
    document_5,
    document_6,
    document_7,
    document_8,
    document_9,
    document_10,
]
documents
# Out:
# [Document(metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#  Document(metadata={'source': 'tweet'}, page_content="Wow! That was an amazing movie. I can't wait to see it again."),
#  Document(metadata={'source': 'website'}, page_content='Is the new iPhone worth the price? Read this review to find out.'),
#  Document(metadata={'source': 'website'}, page_content='The top 10 soccer players in the world right now.'),
#  Document(metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!'),
#  Document(metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.'),
#  Document(metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :(')]

# %%
documents
# Out:
# [Document(metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#  Document(metadata={'source': 'tweet'}, page_content="Wow! That was an amazing movie. I can't wait to see it again."),
#  Document(metadata={'source': 'website'}, page_content='Is the new iPhone worth the price? Read this review to find out.'),
#  Document(metadata={'source': 'website'}, page_content='The top 10 soccer players in the world right now.'),
#  Document(metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!'),
#  Document(metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.'),
#  Document(metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :(')]

# %%
vector_store.add_documents(documents=documents)
# Out:
# ['b0f99049849c4758905ef9c7c1b91131',
#  '441a4fea0bc04edf831f438c8ff7d62b',
#  '0dc1ce83e7924ecea40bfc82915c4dda',
#  '5464a2f6affc448ea4e0a981c735a6dc',
#  '0a0164aceaad4a22803470379496b9a3',
#  '4d96de34e7d54261823c22a74c17646c',
#  '5d0ca857a040408f80b5ee7b565f9700',
#  '37fad0b67ac3443fa93239ca2e91000d',
#  '429822d175274fce9decc4499c3b448c',
#  '1d23aa8da5474d3ebe1be2fce4a8dcee']

# %%
# Search from vector store DB
vector_store.similarity_search("What is the weather")
# Out:
# [Document(id='441a4fea0bc04edf831f438c8ff7d62b', metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(id='429822d175274fce9decc4499c3b448c', metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.'),
#  Document(id='0dc1ce83e7924ecea40bfc82915c4dda', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(id='1d23aa8da5474d3ebe1be2fce4a8dcee', metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :(')]

# %%
results = vector_store.similarity_search(
    "LangChain provides abstractions to make working with LLMs easy",
    k=3,
    filter={"source": "tweet"},
)
for res in results:
    print(f'* "{res.page_content}", metadata={res.metadata}')
# Out:
# * "Building an exciting new project with LangChain - come check it out!", metadata={'source': 'tweet'}
# * "LangGraph is the best framework for building stateful, agentic applications!", metadata={'source': 'tweet'}
# * "Wow! That was an amazing movie. I can't wait to see it again.", metadata={'source': 'tweet'}

# %%
results = vector_store.similarity_search_with_score(
    "LangChain provides abstractions to make working with LLMs easy",
    k=3,
    filter={"source": "tweet"},
)
for res, score in results:
    print(f'* [SIM={score:.2f}] "{res.page_content}", metadata={res.metadata}')
# Out:
# * [SIM=0.72] "Building an exciting new project with LangChain - come check it out!", metadata={'source': 'tweet'}
# * [SIM=0.71] "LangGraph is the best framework for building stateful, agentic applications!", metadata={'source': 'tweet'}
# * [SIM=0.53] "Wow! That was an amazing movie. I can't wait to see it again.", metadata={'source': 'tweet'}

# %%
### Retriever
retriever=vector_store.as_retriever(
  search_type="similarity_score_threshold",
    search_kwargs={"k": 1, "score_threshold": 0.5},
)
retriever.invoke("Stealing from the bank is a crime", filter={"source": "news"})
# Out:
# [Document(id='5464a2f6affc448ea4e0a981c735a6dc', metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.')]

# %%
### Retriever
retriever=vector_store.as_retriever(
  search_type="mmr",
    search_kwargs={"k": 1, "score_threshold": 0.5},
)
retriever.invoke("Stealing from the bank is a crime", filter={"source": "news"})
# Out:
# [Document(id='5464a2f6affc448ea4e0a981c735a6dc', metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.')]
