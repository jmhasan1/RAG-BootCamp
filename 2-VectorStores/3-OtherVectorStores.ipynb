# %% [markdown]
# ### InMemoryVectorStore
# In-memory vector store implementation.
#
# Uses a dictionary, and computes cosine similarity for search using numpy.

# %%
import os
from dotenv import load_dotenv

os.environ["OPENAI_API_KEY"] =  os.getenv("OPENAI_API_KEY")

from langchain.chat_models import init_chat_model

llm = init_chat_model(model="gpt-4.1-nano-2025-04-14")
llm
# Out:
# ChatOpenAI(output_version=None, client=<openai.resources.chat.completions.completions.Completions object at 0x000001CA9D8E7620>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001CA9DDF41A0>, root_client=<openai.OpenAI object at 0x000001CA9D8E4AD0>, root_async_client=<openai.AsyncOpenAI object at 0x000001CA9D8E7E00>, model_name='gpt-4.1-nano-2025-04-14', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True)

# %%
from langchain_openai import OpenAIEmbeddings

from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embedding=OpenAIEmbeddings())

# %%
from langchain_core.documents import Document

document_1 = Document(
    page_content="I had chocolate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
)

documents = [
    document_1,
    document_2,
    document_3,
    document_4,
    document_5,
    document_6,
    document_7,
    document_8,
    document_9,
    document_10,
]

# %%
documents
# Out:
# [Document(metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#  Document(metadata={'source': 'tweet'}, page_content="Wow! That was an amazing movie. I can't wait to see it again."),
#  Document(metadata={'source': 'website'}, page_content='Is the new iPhone worth the price? Read this review to find out.'),
#  Document(metadata={'source': 'website'}, page_content='The top 10 soccer players in the world right now.'),
# ...

# %%
vector_store.add_documents(documents=documents)
# Out:
# ['fbb45fba-232b-4716-a6f0-f97de109bd15',
#  '99458ecd-f0ac-4dcb-84b7-fd913fea6045',
#  '48eeb49f-16f2-45ba-ba4e-a44ac5ffa462',
#  '761a4e52-f367-4cf3-9d8b-3ed103edbf19',
#  'd04fa700-9fca-4f4e-a8d6-adedc9c3e1b5',
#  '2b0929de-59a5-40d1-b83b-f704bb62af03',
#  '175da718-bb7f-4533-8653-f24b565847ad',
#  '4d1f286d-a8a3-4c80-a974-800acb4463aa',
#  'be0014ac-a306-4a0c-a599-19c7dc7321c0',
#  '40acd18f-de38-4bd5-977c-fb2235382fb4']

# %%
vector_store.similarity_search("hows the weather forecast")
# Out:
# [Document(id='99458ecd-f0ac-4dcb-84b7-fd913fea6045', metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(id='be0014ac-a306-4a0c-a599-19c7dc7321c0', metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.'),
#  Document(id='40acd18f-de38-4bd5-977c-fb2235382fb4', metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :('),
#  Document(id='175da718-bb7f-4533-8653-f24b565847ad', metadata={'source': 'website'}, page_content='The top 10 soccer players in the world right now.')]

# %%
vector_store.similarity_search("hows the weather forecast" , k=2)
# Out:
# [Document(id='99458ecd-f0ac-4dcb-84b7-fd913fea6045', metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(id='be0014ac-a306-4a0c-a599-19c7dc7321c0', metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.')]

# %%
# vector_store.similarity_search_with_relevance_scores("Did you have chocolate chips")

# %%
# vector store to retriver
retriever = vector_store.as_retriever()

retriever
# Out:
# VectorStoreRetriever(tags=['InMemoryVectorStore', 'OpenAIEmbeddings'], vectorstore=<langchain_core.vectorstores.in_memory.InMemoryVectorStore object at 0x000001CA9DDF67B0>, search_kwargs={})

# %%
retriever.invoke("Did you have chocolate pie")
# Out:
# [Document(id='fbb45fba-232b-4716-a6f0-f97de109bd15', metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(id='d04fa700-9fca-4f4e-a8d6-adedc9c3e1b5', metadata={'source': 'tweet'}, page_content="Wow! That was an amazing movie. I can't wait to see it again."),
#  Document(id='761a4e52-f367-4cf3-9d8b-3ed103edbf19', metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#  Document(id='40acd18f-de38-4bd5-977c-fb2235382fb4', metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :(')]

# %%
retriever = vector_store.as_retriever(search_kwargs={"k":2})

retriever
# Out:
# VectorStoreRetriever(tags=['InMemoryVectorStore', 'OpenAIEmbeddings'], vectorstore=<langchain_core.vectorstores.in_memory.InMemoryVectorStore object at 0x000001CA9DDF67B0>, search_kwargs={'k': 2})

# %%
retriever.invoke("Did you have chocolate pie")
# Out:
# [Document(id='fbb45fba-232b-4716-a6f0-f97de109bd15', metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(id='d04fa700-9fca-4f4e-a8d6-adedc9c3e1b5', metadata={'source': 'tweet'}, page_content="Wow! That was an amazing movie. I can't wait to see it again.")]
