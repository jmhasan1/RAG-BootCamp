# %% [markdown]
# ### Models Integration With OpenAI, Google Gemini (later) and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
# os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4o-mini-2024-07-18")
model
# Out:
# ChatOpenAI(output_version=None, client=<openai.resources.chat.completions.completions.Completions object at 0x0000017E17643380>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000017E17643E00>, root_client=<openai.OpenAI object at 0x0000017E17640830>, root_async_client=<openai.AsyncOpenAI object at 0x0000017E17643B60>, model_name='gpt-4o-mini-2024-07-18', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True)

# %%
## invoke the model
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 12, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_07be26b212', 'id': 'chatcmpl-E4AGHhbctRVe460uYqW8jhtvg35fc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f861c-d45b-7880-a23d-de59d41b1c77-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 29, 'total_tokens': 41, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
### ChatOpenAI

from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4.1")
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a program, so I don't have feelings, but I'm ready to help you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 12, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_5e8833dc3f', 'id': 'chatcmpl-E4AsEw81WChYGZaJRALZbBXg7VXs4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8640-bc43-77f3-beca-7c114b414347-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 27, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# 'Hello! I’m just a virtual assistant, so I don’t have feelings, but I’m here and ready to help you. How can I assist you today?'

# %% [markdown]
# ### Google Gemini Model Integration

# %%
# import os
# from langchain.chat_models import init_chat_model

# os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# model = init_chat_model("google_genai:gemini-2.5-flash")
# response = model.invoke("Why do parrots talk?")
# response.content

# %%
# import os
# from langchain_google_genai import ChatGoogleGenerativeAI



# model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
# response = model.invoke("Why do parrots talk?")
# response

# %% [markdown]
# ### GROQ MODEL Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3.6-27b")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "Why do parrots talk?" This is a straightforward scientific/biological question about parrot vocalization and mimicry.\n\n2.  **Identify Key Concepts**:\n   - Parrots are known for mimicking human speech\n   - This isn\'t "talking" in the human sense (understanding language)\n   - It\'s vocal mimicry\n   - Evolutionary/social reasons behind mimicry\n   - Biological mechanisms (syrinx, brain structure)\n   - Social bonding, communication within flocks\n   - Captivity vs. wild behavior\n\n3.  **Structure the Answer**:\n   - Clarify what "talking" really means in parrots\n   - Explain the biological mechanism\n   - Discuss evolutionary/social reasons\n   - Differentiate between wild and captive behavior\n   - Note cognitive aspects (limited understanding vs. pattern recognition)\n   - Keep it clear, accurate, and accessible\n\n4.  **Draft - Section by Section**:\n   *(Introductio
# ...

# %%
import os
from langchain_groq import ChatGroq



model = ChatGroq(model="qwen/qwen3.6-27b")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "Why do parrots talk?" This is a common question about parrot vocalization and speech mimicry.\n\n2.  **Identify Key Concepts**:\n   - Parrots are known for mimicking human speech\n   - It\'s not "talking" in the human sense (language comprehension/production)\n   - It\'s about vocal mimicry, social bonding, communication within species, and cognitive abilities\n   - Key factors: syrinx anatomy, brain structure (vocal learning centers), social nature, evolutionary adaptation\n\n3.  **Scientific Explanation**:\n   - **Vocal Learning**: Parrots are vocal learners, like humans, songbirds, and some mammals. They can acquire new sounds through hearing and practice.\n   - **Anatomy**: They have a specialized vocal organ called the syrinx, which allows precise control over pitch, tone, and volume.\n   - **Brain Structure**: They have specialized neural pathways (e.g., pallial nidopal
# ...

# %% [markdown]
# ### Streaming And Batch
#
# ### Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses.
# Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:
# <p> Read Docs : https://docs.langchain.com/oss/python/langchain/streaming </p>

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Request:**\n   - **Topic:** Artificial Intelligence (AI)\n   - **Format:** Paragraph\n   - **Length:** Exactly/approximately 200 words (I\'ll aim for close to 200, checking word count carefully)\n\n2.  **Key Elements to Include:**\n   - Definition/overview of AI\n   - Core capabilities/applications\n   - Impact on society/industry\n   - Ethical considerations/future outlook\n   - Maintain a cohesive, academic/informative tone\n   - Keep it to one paragraph\n\n3.  **Draft - Mental Writing (iterative refinement):**\n   Artificial intelligence represents a transformative technological paradigm that enables machines to simulate human cognitive functions such as learning, reasoning, perception, and decision-making. Rooted in decades of computational research, modern AI leverages advanced algorithms, vast datasets, and immense processing power to perform tasks that once required human intervention. From natural
# ...

# %%
model.stream("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# <generator object BaseChatModel.stream at 0x0000017E18DB49F0>

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text)
# Out:
# <think>
#
# Thinking
#  Process
# :
#
#
#
# 1
# .
#
#  **
# De
# construct
#  the
#  Request
# :**
#
#
#
#  *
#
#  Topic
# :
#  Artificial
#  Intelligence
#  (
# AI
# ).
#
#
#
#  *
#
#  Length
# :
#  Approximately
#
# 2
# 0
# 0
#  words
# .
#
#
#
#  *
#
#  Format
# :
#  A
#  single
#  paragraph
# .
#
#
#
# 2
# .
#
#  **
# Draft
# ing
#  -
#  Attempt
#
# 1
#  (
# M
# ental
#  or
#  rough
#  text
#  generation
# ):**
#
#
#
#  Artificial
#  Intelligence
#  (
# AI
# )
#  represents
#  a
#  transformative
#  leap
#  in
#  technology
# ,
#  mim
# icking
#  human
#  cognitive
#  functions
#  such
#  as
#  learning
# ,
#  reasoning
# ,
#  and
#  problem
# -solving
#  to
#  revolution
# ize
#  industries
#  globally
# .
#  At
#  its
#  core
# ,
#  AI
#  encompasses
#  machine
#  learning
#  and
#  deep
#  learning
#  algorithms
#  that
#  enable
#  systems
#  to
#  analyze
#  vast
#  datasets
# ,
#  recognize
#  patterns
# ,
#  and
#  make
#  predictions
#  with
#  unprecedented
#  accuracy
# ...

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text , end="|" , flush=True)
# Out:
# |
# <think>
# |Here|'s| a| thinking| process|:|
#
# |1|.| | **|An|alyze| User| Input|:**|
# |  | -| **|Topic|:**| Artificial| Intelligence|
# |  | -| **|Format|:**| Paragraph|
# |  | -| **|Length|:**| Approximately| |2|0|0| words|
#
# |2|.| | **|Ident|ify| Key| Themes|/|Concept|s| about| AI|:**|
# |  | -| Definition|/|What| it| is|
# |  | -| Cap|abilities|/App|lications|
# |  | -| Impact| on| society|/e|conomy|
# |  | -| Challenges|/E|th|ical| considerations|
# |  | -| Future| outlook|
#
# |3|.| | **|Draft| -| Mental| Writing| (|aim|ing| for| ~|2|0|0| words|):**|
# ...

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content='Parrots have colorful feathers for several important reasons:\n\n1. **Mate Attraction:** Bright, vibrant plumage is often used to attract mates. Healthy, well-fed parrots can grow more colorful and shiny feathers, signaling to potential mates that they have good genes and are fit for reproduction.\n\n2. **Species and Individual Recognition:** Different parrot species—and even individuals within a species—often have unique color patterns. This helps them recognize each other, find partners, and maintain social bonds within flocks.\n\n3. **Camouflage:** Surprisingly, bright colors can actually help parrots blend into their natural environment. Many parrots live in tropical forests where the light is dappled and the canopy is full of colorful flowers, fruits, berries, and leaves. Their feathers can help them hide from predators by breaking up their outline.\n\n4. **Communication:** Parrots may use their colorful feathers to communicate mood or intent to others, like s
# ...

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end = "", flush=True)
# Out:
# Parrots have colorful feathers for several important reasons related to their biology and environment:
#
# **1. Camouflage:**
# Many parrot species live in forests with dappled sunlight, colorful fruits, and green leaves. Their bright feathers can actually help them blend into these vibrant backgrounds, making it harder for predators to spot them.
#
# **2. Communication:**
# Colorful plumage is used in social signaling. Parrots use their feathers to attract mates, signal their health and fitness, and establish dominance. Bright colors often indicate a healthy, strong individual, which is attractive during mating.
#
# **3. Species and Mate Recognition:**
# Distinctive color patterns help parrots recognize members of their own species or even specific individuals. This is especially important in habitats where many parrot species live together.
#
# **4. Warning to Predators:**
# ...

# %%
for chunk in model.stream("Why Ronaldo is the GOAT , and what gives him edge over Messi while choosing the best of the two , even though skill wise both are unmatchable by any? Still , many regard Ronaldo as the best of the two , why is that so?"):
    print(chunk.text, end = "", flush=True)
# Out:
# This is a classic and highly debated football question: **Why do many consider Cristiano Ronaldo the GOAT and, specifically, what gives him the edge over Lionel Messi, even though both are extraordinary and unmatched in skill?**
#
# Let’s break down the main arguments often made by those who choose Ronaldo over Messi:
#
# ---
#
# ## 1. **Physical Attributes and Athleticism**
# - **Genetic freak**: Ronaldo’s physique, speed, jumping ability, and overall athleticism are legendary. He’s scored many goals simply because he can do things physically that even elite players can’t match.
# - **Longevity and adaptability**: His physical maintenance and fitness from age 18 into late 30s is remarkable; he’s remained world-class across leagues, teams, and ages.
#
# ---
#
# ## 2. **Versatility**
# ...

# %% [markdown]
# #### Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content='Parrots have colorful feathers for several reasons related to **evolution, survival, and communication**:\n\n### 1. **Mating and Attraction**\n- Bright colors help parrots attract mates. In many species, the more vibrant the feathers, the healthier and more attractive the bird appears to potential partners.\n- Coloration signals genetic fitness, which is important for reproductive success.\n\n### 2. **Camouflage**\n- Surprisingly, colorful feathers can help with camouflage in a parrot’s natural habitat.\n- Parrots often live in rainforests with dappled light, colorful flowers, fruits, and leaves. Their vivid plumage helps them blend into the bright, complex environments, making it harder for predators to spot them.\n\n### 3. **Species and Individual Identification**\n- Color patterns help parrots recognize each other. This is useful for identifying members of their own species, finding flock mates, or recognizing mates and offspring.\n- Some species and even sexes have diffe
# ...

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content='Parrots have colorful feathers for several reasons, mainly related to **function and evolution**:\n\n1. **Communication and Mating:** Bright, varied plumage helps parrots communicate with each other, recognize individuals, and show off to potential mates. In many species, having more vibrant feathers can indicate good health or genetic fitness, making those birds more attractive for breeding.\n\n2. **Camouflage:** Although it seems odd, a parrot’s colorful feathers actually help to camouflage them in their natural environments. Parrots often live in lush, dappled rainforests full of green leaves, flowers, and fruits. Their mixed feather colors of greens, reds, blues, and yellows blend in with the light and shadows of the foliage.\n\n3. **Species and Individual Identification:** Color patterns help parrots distinguish members of their own species or social group, which is important for forming flocks, finding mates, and avoiding inbreeding.\n\n4. **Deterring Predat
# ...
