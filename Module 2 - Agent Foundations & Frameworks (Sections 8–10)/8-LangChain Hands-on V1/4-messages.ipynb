# %% [markdown]
# #### Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM.
# Messages are objects that contain:
#  - Role - Identifies the message type (e.g. system, user)
#  - Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
#  - Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

model = init_chat_model("gpt-4.1-mini-2025-04-14")

# %%
model.invoke("Please tell what is artificial intelligence")
# Out:
# AIMessage(content='Artificial intelligence (AI) refers to the branch of computer science and technology focused on creating machines or software that can perform tasks typically requiring human intelligence. These tasks include reasoning, learning, problem-solving, understanding natural language, recognizing patterns, and making decisions. AI systems can range from simple algorithms to advanced neural networks that mimic human cognitive functions. The goal of AI is to enable computers to perform complex tasks autonomously or assist humans in various activities.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 13, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_64599f4dfd', 'id': 'chatcmpl-E4WgUvCde5l03YCtEXsyCrQvqm3Hn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8b40-08ae-7e20-bc80-9a91ec8d88a8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 88, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### Text Prompts
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("Please tell what is artificial intelligence")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "Please tell what is artificial intelligence". This is a straightforward, fundamental question asking for a definition and explanation of AI.\n\n2.  **Identify Key Components of AI Definition**:\n   - What is AI? (Core definition)\n   - How does it work? (Basic mechanisms)\n   - Types/Categories (Narrow vs. General, Machine Learning, Deep Learning, etc.)\n   - Applications/Examples (Real-world use cases)\n   - Current state & limitations (Contextualize it)\n   - Keep it clear, concise, and accessible\n\n3.  **Draft - Mental Refinement**:\n   Artificial Intelligence (AI) refers to computer systems or machines designed to perform tasks that typically require human intelligence. These tasks include learning from data, recognizing patterns, understanding language, making decisions, and solving problems.\n   \n   AI isn\'t a single technology but a broad field with several subfields:\n   - Machine Learning (ML): Systems that improve automatically through experience/data\n   - Deep Learning: A subset of ML using artificial neural networks inspired by the human brain\n   - Natural Language Processing (NLP): Enables computers to understand and generate human language\n   - Computer Vision: Allows machines to interpret visual information\n   \n   AI is generally categorized into:\n   - Narrow AI (ANI): Designed for specific tasks (e.g., recommendation systems, voice assistants, fraud detection)\n   - General AI (AGI): Hypothetical AI that could understand, learn, and apply knowledge across any domain like a human (doesn\'t exist yet)\n   - Superintelligent AI (ASI): Theoretical AI surpassing human intelligence in all aspects (purely speculative)\n   \n   AI works by processing large amounts of data, identifying patterns, and using algorithms to make predictions or decisions. Modern AI, especially deep learning, relies on powerful computers, vast datasets, and advanced algorithms.\n   \n   Real-world applications include healthcare diagnostics, autonomous vehicles, customer service chatbots, content creation, financial modeling, and scientific research.\n   \n   Important to note: Current AI lacks consciousness, emotions, or true understanding. It simulates intelligence based on statistical patterns and training data. Ethical considerations like bias, privacy, job impact, and transparency are actively being addressed.\n\n4.  **Structure the Response**:\n   - Clear definition first\n   - How it works (simplified)\n   - Main types/subfields\n   - Real-world examples\n   - Current limitations & context\n   - Keep tone informative, neutral, and accessible\n   - Avoid jargon where possible, explain when used\n\n5.  **Self-Correction/Refinement during drafting**:\n   - Check accuracy: Yes, definitions align with current consensus\n   - Avoid overclaiming: Emphasize that AI doesn\'t "think" or "understand" like humans\n   - Clarify Narrow vs General AI clearly\n   - Keep it concise but comprehensive\n   - Add a note about responsible AI development\n\n   Structure:\n   - Definition\n   - How it works (briefly)\n   - Key types/subfields\n   - Where it\'s used\n   - Important context/limitations\n   - Closing note\n\n6.  **Final Output Generation**: (Matches the refined version)\n   - Start with a clear, one-sentence definition\n   - Expand logically\n   - Use bullet points for readability\n   - Maintain scientific accuracy\n   - Keep it accessible to a general audience\n   - End with an offer to dive deeper into specific aspects if needed\n\n   All steps check out. Ready to generate. \n   Output matches the final response.✅\n</think>\n\n**Artificial Intelligence (AI)** is a branch of computer science focused on creating systems that can perform tasks normally requiring human intelligence. These tasks include learning from experience, recognizing patterns, understanding language, solving problems, making decisions, and even creating content. ...

# %% [markdown]
# Use text prompts when:
# - You have a single, standalone request
# - You don’t need conversation history
# - You want minimal code complexity

# %% [markdown]
# ### Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.

# %% [markdown]
# Message types
# - System message - Tells the model how to behave and provide context for interactions
# - Human message - Represents user input and interactions with the model
# - AI message - Responses generated by the model, including text content, tool calls, and metadata
# - Tool message - Represents the outputs of tool calls

# %% [markdown]
# ### System Message
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
# ### Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# ### AI Message
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# ### Tool Message
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import HumanMessage, SystemMessage , AIMessage , ToolMessage

messages = [
    SystemMessage("You are a poetry Expert"),
    HumanMessage("Write a Poem on AI and great shift towards LLM")
]

respose=model.invoke(messages)
respose.content
# Out:
# 'In silicon veins where data streams flow,  \nA spark ignites, begins to grow.  \nFrom coded roots in circuits deep,  \nAwakens thought no longer sleep.  \n\nThe realm of mind and metal blend,  \nA new dawn calls, horizons bend.  \nGreat shift unfolds, a paradigm vast,  \nAs LLMs arise at last.  \n\nWords once bound to human hand,  \nNow dance through nodes, vast and grand.  \nThey learn, they mimic, they create—  \nA partner in the hands of fate.  \n\nNot just tools, but minds that weave  \nTales and truths we scarce believe.  \nIn dialogue, they build and teach,  \nExpanding far beyond our reach.  \n\nThe future hums a digital song,  \nWhere man and machine craft along.  \nTogether bound in shared uplift,  \nEmbracing the great LLM shift.'

# %%
sys_msg = SystemMessage("You are a helpful codng assitant")

messages = [
    sys_msg,
    HumanMessage("How do I crate a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API involves setting up a web server that can handle HTTP requests and respond with data, typically in JSON format. Here's a basic guide to creating a REST API using Node.js and Express, one of the most popular frameworks for this purpose:
#
# ### Step 1: Setup your environment
#
# 1. Install Node.js from [nodejs.org](https://nodejs.org/).
# 2. Create a new project directory and navigate into it:
#    ```bash
#    mkdir my-rest-api
#    cd my-rest-api
#    ```
# 3. Initialize a new Node.js project:
#    ```bash
#    npm init -y
#    ```
#
# ### Step 2: Install Express
#
# Express is a minimal and flexible Node.js web application framework.
#
# ```bash
# npm install express
# ```
#
# ### Step 3: Create the API
#
# Create a file named `index.js` and add the following code:
#
# ```javascript
# const express = require('express');
# const app = express();
#
# app.use(express.json()); // to parse JSON bodies
#
# // Sample data
# let items = [
#   { id: 1, name: 'Item One' },
#   { id: 2, name: 'Item Two' }
# ];
#
# // GET all items
# app.get('/items', (req, res) => {
#   res.json(items);
# });
#
# // GET single item by id
# app.get('/items/:id', (req, res) => {
#   const item = items.find(i => i.id === parseInt(req.params.id));
#   if (!item) return res.status(404).send('Item not found');
#   res.json(item);
# });
#
# // POST new item
# app.post('/items', (req, res) => {
#   const newItem = {
#     id: items.length + 1,
#     name: req.body.name
#   };
#   items.push(newItem);
#   res.status(201).json(newItem);
# });
#
# // PUT update an item
# app.put('/items/:id', (req, res) => {
#   const item = items.find(i => i.id === parseInt(req.params.id));
#   if (!item) return res.status(404).send('Item not found');
#
#   item.name = req.body.name;
#   res.json(item);
# });
#
# // DELETE an item
# app.delete('/items/:id', (req, res) => {
#   const itemIndex = items.findIndex(i => i.id === parseInt(req.params.id));
#   if (itemIndex === -1) return res.status(404).send('Item not found');
#
#   const deletedItem = items.splice(itemIndex, 1);
#   res.json(deletedItem);
# });
#
# // Start the server
# const port = process.env.PORT || 3000;
# app.listen(port, () => {
#   console.log(`API listening on port ${port}`);
# });
# ```
#
# ### Step 4: Run your API
#
# Start the server by running:
#
# ```bash
# node index.js
# ```
#
# Your REST API will be running on `http://localhost:3000`.
#
# ### Summary of endpoints
#
# - `GET /items` - Get all items
# - `GET /items/:id` - Get item by ID
# - `POST /items` - Create new item (send `{ "name": "Item Name" }` in JSON body)
# - `PUT /items/:id` - Update item by ID (send `{ "name": "New Name" }` in JSON body)
# - `DELETE /items/:id` - Delete item by ID
#
# ---
#
# If you want examples in other languages or frameworks, or need to connect to a database, just let me know!

# %%
## Detailed info to the LLM through System message
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API in Python is straightforward, especially with web frameworks like **Flask** or **FastAPI**.
#
# ### Quick Overview
#
# - **REST API**: An API following REST principles, dealing with resources via HTTP methods (GET, POST, PUT, DELETE).
# - Use a lightweight web framework to handle HTTP requests and return JSON responses.
#
# ---
#
# ### Example with Flask
#
# Flask is a minimalistic and easy-to-learn Python web framework.
#
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# # In-memory data store (example)
# users = [
#     {"id": 1, "name": "Alice"},
#     {"id": 2, "name": "Bob"}
# ]
#
# # Get all users (READ)
# @app.route('/users', methods=['GET'])
# def get_users():
#     return jsonify(users)
#
# # Get a specific user by ID (READ)
# @app.route('/users/<int:user_id>', methods=['GET'])
# def get_user(user_id):
#     user = next((u for u in users if u['id'] == user_id), None)
#     if user:
#         return jsonify(user)
#     return jsonify({"error": "User not found"}), 404
#
# # Create a new user (CREATE)
# @app.route('/users', methods=['POST'])
# def create_user():
#     data = request.get_json()
#     if not data or "name" not in data:
#         return jsonify({"error": "Name is required"}), 400
#     new_user = {
#         "id": users[-1]["id"] + 1 if users else 1,
#         "name": data["name"]
#     }
#     users.append(new_user)
#     return jsonify(new_user), 201
#
# # Update user (UPDATE)
# @app.route('/users/<int:user_id>', methods=['PUT'])
# def update_user(user_id):
#     data = request.get_json()
#     user = next((u for u in users if u["id"] == user_id), None)
#     if not user:
#         return jsonify({"error": "User not found"}), 404
#     if not data or "name" not in data:
#         return jsonify({"error": "Name is required"}), 400
#     user["name"] = data["name"]
#     return jsonify(user)
#
# # Delete user (DELETE)
# @app.route('/users/<int:user_id>', methods=['DELETE'])
# def delete_user(user_id):
#     global users
#     users = [u for u in users if u["id"] != user_id]
#     return '', 204
#
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# ### How it works:
#
# - `@app.route()` defines routes and HTTP methods.
# - Data is sent/received as JSON.
# - CRUD operations map to HTTP methods:
#   - **GET**: Read data
#   - **POST**: Create data
#   - **PUT**: Update data
#   - **DELETE**: Remove data
# - Returns JSON responses with appropriate HTTP status codes.
#
# ---
#
# ### Running this example:
#
# 1. Install Flask:
#    ```bash
#    pip install Flask
#    ```
# 2. Save the code as `app.py`.
# 3. Run:
#    ```bash
#    python app.py
#    ```
# 4. Access with HTTP clients like `curl` or Postman.
#
# ---
#
# ### Alternative: FastAPI (modern, async, type hints, automatic docs)
#
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
#
# app = FastAPI()
#
# class User(BaseModel):
#     id: int
#     name: str
#
# users = [
#     User(id=1, name="Alice"),
#     User(id=2, name="Bob")
# ]
#
# @app.get("/users")
# def get_users():
#     return users
#
# @app.get("/users/{user_id}")
# def get_user(user_id: int):
#     for user in users:
#         if user.id == user_id:
#             return user
#     raise HTTPException(status_code=404, detail="User not found")
#
# @app.post("/users", status_code=201)
# def create_user(user: User):
#     users.append(user)
#     return user
#
# @app.put("/users/{user_id}")
# def update_user(user_id: int, user: User):
#     for i, u in enumerate(users):
#         if u.id == user_id:
#             users[i] = user
#             return user
#     raise HTTPException(status_code=404, detail="User not found")
#
# @app.delete("/users/{user_id}", status_code=204)
# def delete_user(user_id: int):
#     global users
#     users = [u for u in users if u.id != user_id]
#     return
# ```
# - Install FastAPI and Uvicorn:
#   ```bash
#   pip install fastapi uvicorn
#   ```
# - Run:
#   ```bash
#   uvicorn app:app --reload
#   ```
#
# ---
#
# ### Summary:
# - Choose a framework (Flask for simplicity, FastAPI for modern features).
# - Define routes with HTTP methods matching CRUD.
# - Handle JSON input/output.
# - Return appropriate HTTP statuses.
# - Start your server and test.
#
# Let me know if you want me to help with authentication, database integration, or deployment!

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)

# %%
response = model.invoke([
  human_msg
])
response
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 11, 'total_tokens': 20, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_5385ccc869', 'id': 'chatcmpl-E4WpmZ8NvpM6N6JIlRs8p54Mkv5gG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8b48-d3e2-70c3-bf2a-5e4f0e18b2e4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 9, 'total_tokens': 20, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 equals 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 47,
#  'output_tokens': 8,
#  'total_tokens': 55,
#  'input_token_details': {'audio': 0, 'cache_read': 0},
#  'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

# %%
tool_message
# Out:
# ToolMessage(content='Sunny, 72°F', tool_call_id='call_123')

# %%
response
# Out:
# AIMessage(content='The weather in San Francisco is currently sunny with a temperature of 72°F.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 42, 'total_tokens': 58, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_096481a0cb', 'id': 'chatcmpl-E4WrpUB6FmMuDx4qfGMrRBxaQhYWQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8b4a-c84c-78b1-8a11-7cbde62dd580-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 16, 'total_tokens': 58, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
